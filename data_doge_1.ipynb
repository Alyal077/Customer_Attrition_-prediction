# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
plt.style.use('fivethirtyeight')

# %%
df_train=pd.read_csv('/content/drive/MyDrive/Hackathon/IIT KGP/train.csv')
df_train
# Out:
#                         ID     sex  ... GrandPayment CustomerAttrition
# 0     B60LHTZLLPFU4IULNPUF  Female  ...  4628.129119               Yes
# 1     1RUJ7ONYZHYTWKOKO1SD    Male  ...   922.085998                No
# 2     DZ9EEOQWSN0MYCBUPAM5    Male  ...  6205.891129               Yes
# 3     YZ43L1UQUQACTL1PXXZG    Male  ...  1248.655391                No
# 4     6P28152QGF60PDLSCB9M  Female  ...  1285.321277                No
# ...                    ...     ...  ...          ...               ...
# 6333  Y7U717HO87PCW6XXIQA1  Female  ...   441.914530               Yes
# 6334  NGY3WOQ0OT1P4RHAR0PT  Female  ...    45.308180                No
# 6335  ZBBW7H8AYLZJ2HK5TBBJ    Male  ...   552.181341               Yes
# 6336  BUE75NSSLT2S2URTKZRN    Male  ...  4563.812326                No
# 6337  IRFAYIAO820RIX2GUFFF  Female  ...  5756.542013                No
#
# [6338 rows x 16 columns]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6338 entries, 0 to 6337
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   6338 non-null   object
#  1   sex                  6338 non-null   object
#  2   Aged                 6338 non-null   object
#  3   Married              6338 non-null   object
#  4   TotalDependents      6338 non-null   object
#  5   ServiceSpan          6338 non-null   int64
#  6   MobileService        6338 non-null   object
#  7   4GService            6338 non-null   object
#  8   CyberProtection      6338 non-null   object
#  9   HardwareSupport      6338 non-null   object
#  10  TechnicalAssistance  6338 non-null   object
#  11  FilmSubscription     6338 non-null   object
#  12  SettlementProcess    6338 non-null   object
#  13  QuarterlyPayment     6338 non-null   float64
#  14  GrandPayment         6328 non-null   float64
#  15  CustomerAttrition    6338 non-null   object
# dtypes: float64(2), int64(1), object(13)
# memory usage: 792.4+ KB

# %%
df_train.describe()
# Out:
#        ServiceSpan  QuarterlyPayment  GrandPayment
# count  6338.000000       6338.000000   6328.000000
# mean     31.946040         64.814490   2290.544207
# std      24.559659         30.191091   2265.181098
# min      -2.000000         16.504109     16.297961
# 25%       8.000000         35.645524    401.849530
# 50%      29.000000         70.534085   1407.589119
# 75%      55.000000         90.058498   3823.855846
# max      73.000000        120.159190   8685.848657

# %%
df_train.columns
# Out:
# Index(['ID', 'sex', 'Aged', 'Married', 'TotalDependents', 'ServiceSpan',
#        'MobileService', '4GService', 'CyberProtection', 'HardwareSupport',
#        'TechnicalAssistance', 'FilmSubscription', 'SettlementProcess',
#        'QuarterlyPayment', 'GrandPayment', 'CustomerAttrition'],
#       dtype='object')

# %%
numerical_cols = ['ServiceSpan','QuarterlyPayment', 'GrandPayment']
object_cols = ['sex', 'Aged', 'Married', 'TotalDependents','MobileService', '4GService', 'CyberProtection', 'HardwareSupport',
       'TechnicalAssistance', 'FilmSubscription', 'SettlementProcess']

# %%
#sns.pairplot(df_train,hue='CustomerAttrition')

# %%
def kdeplot(list,df):
  length = len(list)
  for i in range(length):
    plt.figure(figsize=(15, 4))
    plt.subplot(1,3, i+1)
    sns.kdeplot(df[list[i]])

# %%
#kdeplot(list = numerical_cols , df = df_train)

# %%
def boxplot(list,df):
  length = len(list)
  for i in range(length):
    plt.figure(figsize=(15, 4))
    plt.subplot(1,3, i+1)
    sns.boxplot(df[list[i]])

# %%
#boxplot(list = numerical_cols , df = df_train)

# %%
def counterplot(list,df):
  length = len(list)
  for i in range(length):
    plt.figure(figsize=(150 , 10))
    plt.subplot(2,11, i+1)
    sns.countplot(df[list[i]],hue=df['CustomerAttrition'])

# %%
#counterplot(list = object_cols , df = df_train)

# %%
def encoder(x):
    if x=='Yes':
        return 1
    else:
        return 0

# %%
def fn_apl(list,df):
    for column in list:
        df[column] = df[column].apply(encoder)

# %%
yes_no_list_train =['Aged', 'Married', 'TotalDependents','MobileService', 'CyberProtection', 'HardwareSupport',
       'TechnicalAssistance', 'FilmSubscription','CustomerAttrition']

# %%
fn_apl(list = yes_no_list_train ,df=df_train)

# %%
df_train
# Out:
#                         ID     sex  ...  GrandPayment  CustomerAttrition
# 0     B60LHTZLLPFU4IULNPUF  Female  ...   4628.129119                  1
# 1     1RUJ7ONYZHYTWKOKO1SD    Male  ...    922.085998                  0
# 2     DZ9EEOQWSN0MYCBUPAM5    Male  ...   6205.891129                  1
# 3     YZ43L1UQUQACTL1PXXZG    Male  ...   1248.655391                  0
# 4     6P28152QGF60PDLSCB9M  Female  ...   1285.321277                  0
# ...                    ...     ...  ...           ...                ...
# 6333  Y7U717HO87PCW6XXIQA1  Female  ...    441.914530                  1
# 6334  NGY3WOQ0OT1P4RHAR0PT  Female  ...     45.308180                  0
# 6335  ZBBW7H8AYLZJ2HK5TBBJ    Male  ...    552.181341                  1
# 6336  BUE75NSSLT2S2URTKZRN    Male  ...   4563.812326                  0
# 6337  IRFAYIAO820RIX2GUFFF  Female  ...   5756.542013                  0
#
# [6338 rows x 16 columns]

# %%
df_test=pd.read_csv('/content/drive/MyDrive/Hackathon/IIT KGP/test.csv')
df_test
# Out:
#                        ID     sex  ... QuarterlyPayment GrandPayment
# 0    WMORTPCG3HTIPEFSGUFY    Male  ...        21.299937   151.092519
# 1    GBLPEA16C3KGBO57KEFO  Female  ...        56.609623  1553.276979
# 2    IDCQS0CO5P29AMKY3LO1    Male  ...        25.167690  1684.262416
# 3    1IY29SDITYU6IFZ4KJB0  Female  ...        55.560968  1829.874462
# 4    T5XMW5B0YPCONH30WJD2  Female  ...        20.070002   489.818170
# ..                    ...     ...  ...              ...          ...
# 700  8M7JJ5JBQUIA0ORLJ1UU  Female  ...       109.033026  7345.910050
# 701  WS1T1FLY87G9A1UNKST4    Male  ...        71.468072   130.565363
# 702  0XG96FS1KXZSULPSGA1X  Female  ...       102.930468  2392.842382
# 703  YR858QHNQMCDBCT9JRP6  Female  ...        51.862869   263.231362
# 704  IMKOIG7YFZ3KHC2OMFMH  Female  ...        93.666740  3624.437890
#
# [705 rows x 15 columns]

# %%
yes_no_list_test =['Aged', 'Married', 'TotalDependents','MobileService', 'CyberProtection', 'HardwareSupport',
       'TechnicalAssistance', 'FilmSubscription']

# %%
fn_apl(list=yes_no_list_test,df=df_test)

# %%
df_test
# Out:
#                        ID     sex  ...  QuarterlyPayment  GrandPayment
# 0    WMORTPCG3HTIPEFSGUFY    Male  ...         21.299937    151.092519
# 1    GBLPEA16C3KGBO57KEFO  Female  ...         56.609623   1553.276979
# 2    IDCQS0CO5P29AMKY3LO1    Male  ...         25.167690   1684.262416
# 3    1IY29SDITYU6IFZ4KJB0  Female  ...         55.560968   1829.874462
# 4    T5XMW5B0YPCONH30WJD2  Female  ...         20.070002    489.818170
# ..                    ...     ...  ...               ...           ...
# 700  8M7JJ5JBQUIA0ORLJ1UU  Female  ...        109.033026   7345.910050
# 701  WS1T1FLY87G9A1UNKST4    Male  ...         71.468072    130.565363
# 702  0XG96FS1KXZSULPSGA1X  Female  ...        102.930468   2392.842382
# 703  YR858QHNQMCDBCT9JRP6  Female  ...         51.862869    263.231362
# 704  IMKOIG7YFZ3KHC2OMFMH  Female  ...         93.666740   3624.437890
#
# [705 rows x 15 columns]

# %%
df_train['sex']=pd.factorize(df_train.sex)[0]
df_train["4GService"]=pd.factorize(df_train["4GService"])[0]
df_train['SettlementProcess']=pd.factorize(df_train.SettlementProcess)[0]

df_test['sex']=pd.factorize(df_test.sex)[0]
df_test["4GService"]=pd.factorize(df_test["4GService"])[0]
df_test['SettlementProcess']=pd.factorize(df_test.SettlementProcess)[0]

# %%
df_train.ServiceSpan.unique()
# Out:
# array([48, 45, 59, 14, 25, 27, 53,  0,  1, 46, 67, 24, 61, 54,  9, 30, 18,
#         5, 64,  3, 41, 40, 31, 21, 15,  6, 69, 72, 33, 71,  2, 36,  8, 37,
#        34, 28, -1, 60, 22, 68, 11, 39, 58, 10, 50,  4, 44, 49, 38, 55, 51,
#        16, 65, 13, 26, 19, 57, 70, 73, 42, 35, 62, 23, 56, 47, 63, 32, 29,
#         7, 20, 43, 12, 52, 17, 66, -2])

# %%
df_train
# Out:
#                         ID  sex  ...  GrandPayment  CustomerAttrition
# 0     B60LHTZLLPFU4IULNPUF    0  ...   4628.129119                  1
# 1     1RUJ7ONYZHYTWKOKO1SD    1  ...    922.085998                  0
# 2     DZ9EEOQWSN0MYCBUPAM5    1  ...   6205.891129                  1
# 3     YZ43L1UQUQACTL1PXXZG    1  ...   1248.655391                  0
# 4     6P28152QGF60PDLSCB9M    0  ...   1285.321277                  0
# ...                    ...  ...  ...           ...                ...
# 6333  Y7U717HO87PCW6XXIQA1    0  ...    441.914530                  1
# 6334  NGY3WOQ0OT1P4RHAR0PT    0  ...     45.308180                  0
# 6335  ZBBW7H8AYLZJ2HK5TBBJ    1  ...    552.181341                  1
# 6336  BUE75NSSLT2S2URTKZRN    1  ...   4563.812326                  0
# 6337  IRFAYIAO820RIX2GUFFF    0  ...   5756.542013                  0
#
# [6338 rows x 16 columns]

# %%
df_test
# Out:
#                        ID  sex  ...  QuarterlyPayment  GrandPayment
# 0    WMORTPCG3HTIPEFSGUFY    0  ...         21.299937    151.092519
# 1    GBLPEA16C3KGBO57KEFO    1  ...         56.609623   1553.276979
# 2    IDCQS0CO5P29AMKY3LO1    0  ...         25.167690   1684.262416
# 3    1IY29SDITYU6IFZ4KJB0    1  ...         55.560968   1829.874462
# 4    T5XMW5B0YPCONH30WJD2    1  ...         20.070002    489.818170
# ..                    ...  ...  ...               ...           ...
# 700  8M7JJ5JBQUIA0ORLJ1UU    1  ...        109.033026   7345.910050
# 701  WS1T1FLY87G9A1UNKST4    0  ...         71.468072    130.565363
# 702  0XG96FS1KXZSULPSGA1X    1  ...        102.930468   2392.842382
# 703  YR858QHNQMCDBCT9JRP6    1  ...         51.862869    263.231362
# 704  IMKOIG7YFZ3KHC2OMFMH    1  ...         93.666740   3624.437890
#
# [705 rows x 15 columns]

# %%
df_train['GrandPayment'] = df_train['GrandPayment'].fillna(0)

# %%
df_train['QuarterlyPayment'] = np.round(df_train['QuarterlyPayment'])
df_train['GrandPayment'] = np.round(df_train['GrandPayment'])

# %%
df_train
# Out:
#                         ID  sex  ...  GrandPayment  CustomerAttrition
# 0     B60LHTZLLPFU4IULNPUF    0  ...        4628.0                  1
# 1     1RUJ7ONYZHYTWKOKO1SD    1  ...         922.0                  0
# 2     DZ9EEOQWSN0MYCBUPAM5    1  ...        6206.0                  1
# 3     YZ43L1UQUQACTL1PXXZG    1  ...        1249.0                  0
# 4     6P28152QGF60PDLSCB9M    0  ...        1285.0                  0
# ...                    ...  ...  ...           ...                ...
# 6333  Y7U717HO87PCW6XXIQA1    0  ...         442.0                  1
# 6334  NGY3WOQ0OT1P4RHAR0PT    0  ...          45.0                  0
# 6335  ZBBW7H8AYLZJ2HK5TBBJ    1  ...         552.0                  1
# 6336  BUE75NSSLT2S2URTKZRN    1  ...        4564.0                  0
# 6337  IRFAYIAO820RIX2GUFFF    0  ...        5757.0                  0
#
# [6338 rows x 16 columns]

# %% [markdown]
# #Trial

# %%
df_train=df_train.drop(labels=['ID'],axis=1)

# %%
from sklearn.preprocessing import MinMaxScaler
mm_scaler = MinMaxScaler()
col_names_train = list(df_train.columns)
df_mm_train = mm_scaler.fit_transform( df_train )
df_mm_train = pd.DataFrame(df_mm_train, columns=col_names_train)
df_train = df_mm_train

# %%
df_train['CustomerAttrition'] = df_train['CustomerAttrition'].astype('int64')

# %%
#df_train = df_train[df_train['ServiceSpan'] != -1]

# %%
df_train = df_train[df_train['ServiceSpan'] != -2]

# %%
import imblearn
print(imblearn.__version__)
from imblearn.over_sampling import SMOTE
from collections import Counter
# Out:
# 0.4.3

# %%
train, test = train_test_split(df_train, test_size=0.2,shuffle=True,random_state=2021)
test.head(5)
# Out:
#       sex  Aged  Married  ...  QuarterlyPayment  GrandPayment  CustomerAttrition
# 751   0.0   0.0      1.0  ...          0.708738      0.280221                  0
# 4712  1.0   0.0      0.0  ...          0.572816      0.355630                  0
# 148   1.0   0.0      0.0  ...          0.650485      0.345614                  0
# 2163  1.0   0.0      0.0  ...          0.504854      0.139535                  0
# 5805  1.0   1.0      0.0  ...          0.533981      0.023371                  1
#
# [5 rows x 15 columns]

# %%
a=train.drop(labels='CustomerAttrition',axis=1)
xtrain=a#[['GrandPayment','QuarterlyPayment','ServiceSpan','SettlementProcess']]
ytrain=train['CustomerAttrition']
b =test.drop(labels='CustomerAttrition',axis=1)
xtest=b#[['GrandPayment','QuarterlyPayment','ServiceSpan','SettlementProcess']]
ytest=test['CustomerAttrition']

# %%
oversample = SMOTE()
xtrain, ytrain = oversample.fit_resample(xtrain, ytrain)
counter = Counter(ytrain)
print(counter)
# Out:
# Counter({0: 3758, 1: 3758})
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function safe_indexing is deprecated; safe_indexing is deprecated in version 0.22 and will be removed in version 0.24.
#   warnings.warn(msg, category=FutureWarning)

# %%
from sklearn.metrics import accuracy_score as score

# %%
from sklearn.neighbors import KNeighborsClassifier
neigh = KNeighborsClassifier(n_neighbors=5)
neigh.fit(xtrain, ytrain)
print(score(ytrain,neigh.predict(xtrain)))
print(score(ytest,neigh.predict(xtest) ))
# Out:
# 0.8553751995742416
# 0.7026813880126183

# %%
lr = LogisticRegression()

# %%
from sklearn.metrics import accuracy_score 
score = accuracy_score()
rfc= RandomForestClassifier(max_depth = 5)#,max_depth=12,min_samples_split=437,max_leaf_nodes=300,min_samples_leaf=115,n_estimators=12)
rfc.fit(xtrain, ytrain)
print("RandomForestClassifier accu")
print(score(ytrain,rfc.predict(xtrain)))
print(score(ytest,rfc.predict(xtest) ))
# Out:
# RandomForestClassifier accu
# 0.7860564129856307
# 0.7657728706624606

# %%
from sklearn.svm import SVC
svc = SVC(C=1000, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
    decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
    probability=False, random_state=None, shrinking=True, tol=0.001,
    verbose=False)
svc.fit(xtrain, ytrain)

print(score(ytrain,svc.predict(xtrain)))
print(score(ytest,svc.predict(xtest) ))
# Out:
# 0.9618147951037787
# 0.7255520504731862

# %%
from sklearn.model_selection import GridSearchCV
  
# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000], 
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['rbf']} 
  
grid = GridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
  
# fitting the model for grid search
grid.fit(xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.731, total=   1.9s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.9s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.740, total=   1.9s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.8s remaining:    0.0s
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.792, total=   2.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.768, total=   2.0s
# [CV] C=0.1, gamma=1, kernel=rbf ......................................
# [CV] .......... C=0.1, gamma=1, kernel=rbf, score=0.775, total=   2.0s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.736, total=   1.9s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.729, total=   1.9s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.766, total=   1.9s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.757, total=   1.9s
# [CV] C=0.1, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=0.1, gamma=0.1, kernel=rbf, score=0.762, total=   1.9s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.715, total=   2.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.715, total=   2.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.737, total=   2.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.721, total=   2.2s
# [CV] C=0.1, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=0.1, gamma=0.01, kernel=rbf, score=0.727, total=   2.2s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.659, total=   2.5s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=0.1, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=0.1, gamma=0.001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.659, total=   2.5s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=0.1, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=0.1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.765, total=   1.6s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.774, total=   1.6s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.820, total=   1.7s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.818, total=   1.7s
# [CV] C=1, gamma=1, kernel=rbf ........................................
# [CV] ............ C=1, gamma=1, kernel=rbf, score=0.826, total=   1.7s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.740, total=   1.6s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.744, total=   1.6s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.780, total=   1.6s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.770, total=   1.6s
# [CV] C=1, gamma=0.1, kernel=rbf ......................................
# [CV] .......... C=1, gamma=0.1, kernel=rbf, score=0.779, total=   1.6s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.743, total=   1.8s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.737, total=   1.8s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.765, total=   1.8s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.758, total=   1.8s
# [CV] C=1, gamma=0.01, kernel=rbf .....................................
# [CV] ......... C=1, gamma=0.01, kernel=rbf, score=0.766, total=   1.8s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.717, total=   2.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.717, total=   2.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.738, total=   2.1s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.722, total=   2.2s
# [CV] C=1, gamma=0.001, kernel=rbf ....................................
# [CV] ........ C=1, gamma=0.001, kernel=rbf, score=0.728, total=   2.2s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.659, total=   2.5s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.4s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=1, gamma=0.0001, kernel=rbf ...................................
# [CV] ....... C=1, gamma=0.0001, kernel=rbf, score=0.500, total=   2.5s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.783, total=   1.7s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.802, total=   1.8s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.835, total=   1.9s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.844, total=   1.9s
# [CV] C=10, gamma=1, kernel=rbf .......................................
# [CV] ........... C=10, gamma=1, kernel=rbf, score=0.848, total=   1.9s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.739, total=   1.8s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.750, total=   1.8s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.794, total=   1.9s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.784, total=   1.8s
# [CV] C=10, gamma=0.1, kernel=rbf .....................................
# [CV] ......... C=10, gamma=0.1, kernel=rbf, score=0.802, total=   1.9s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.733, total=   1.6s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.732, total=   1.6s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.766, total=   1.7s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.752, total=   1.6s
# [CV] C=10, gamma=0.01, kernel=rbf ....................................
# [CV] ........ C=10, gamma=0.01, kernel=rbf, score=0.770, total=   1.6s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.742, total=   1.8s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.735, total=   1.7s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.766, total=   1.8s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.755, total=   1.8s
# [CV] C=10, gamma=0.001, kernel=rbf ...................................
# [CV] ....... C=10, gamma=0.001, kernel=rbf, score=0.766, total=   1.8s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.717, total=   2.1s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.717, total=   2.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.738, total=   2.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.723, total=   2.2s
# [CV] C=10, gamma=0.0001, kernel=rbf ..................................
# [CV] ...... C=10, gamma=0.0001, kernel=rbf, score=0.727, total=   2.2s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.782, total=   2.5s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.792, total=   2.5s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.853, total=   2.7s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.855, total=   2.8s
# [CV] C=100, gamma=1, kernel=rbf ......................................
# [CV] .......... C=100, gamma=1, kernel=rbf, score=0.858, total=   2.8s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.737, total=   2.6s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.767, total=   2.7s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.824, total=   2.9s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.810, total=   2.9s
# [CV] C=100, gamma=0.1, kernel=rbf ....................................
# [CV] ........ C=100, gamma=0.1, kernel=rbf, score=0.824, total=   3.0s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.733, total=   1.9s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.741, total=   1.9s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.776, total=   1.9s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.769, total=   1.9s
# [CV] C=100, gamma=0.01, kernel=rbf ...................................
# [CV] ....... C=100, gamma=0.01, kernel=rbf, score=0.781, total=   1.9s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.740, total=   1.6s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.737, total=   1.6s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.763, total=   1.6s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.747, total=   1.6s
# [CV] C=100, gamma=0.001, kernel=rbf ..................................
# [CV] ...... C=100, gamma=0.001, kernel=rbf, score=0.770, total=   1.6s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.741, total=   1.8s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.736, total=   1.8s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.766, total=   1.8s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.756, total=   1.8s
# [CV] C=100, gamma=0.0001, kernel=rbf .................................
# [CV] ..... C=100, gamma=0.0001, kernel=rbf, score=0.767, total=   1.8s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.774, total=   4.2s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.778, total=   4.9s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.858, total=   5.9s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.850, total=   5.6s
# [CV] C=1000, gamma=1, kernel=rbf .....................................
# [CV] ......... C=1000, gamma=1, kernel=rbf, score=0.873, total=   5.3s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.745, total=   8.6s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.770, total=   7.9s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.825, total=  10.7s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.820, total=   9.4s
# [CV] C=1000, gamma=0.1, kernel=rbf ...................................
# [CV] ....... C=1000, gamma=0.1, kernel=rbf, score=0.840, total=   9.2s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.731, total=   3.1s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.746, total=   3.1s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.790, total=   3.3s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.782, total=   3.2s
# [CV] C=1000, gamma=0.01, kernel=rbf ..................................
# [CV] ...... C=1000, gamma=0.01, kernel=rbf, score=0.800, total=   3.2s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.733, total=   1.9s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.733, total=   1.9s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.768, total=   1.9s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.750, total=   1.9s
# [CV] C=1000, gamma=0.001, kernel=rbf .................................
# [CV] ..... C=1000, gamma=0.001, kernel=rbf, score=0.770, total=   1.9s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.741, total=   1.6s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.737, total=   1.6s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.763, total=   1.6s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.747, total=   1.6s
# [CV] C=1000, gamma=0.0001, kernel=rbf ................................
# [CV] .... C=1000, gamma=0.0001, kernel=rbf, score=0.768, total=   1.6s
# [Parallel(n_jobs=1)]: Done 125 out of 125 | elapsed:  5.1min finished
# GridSearchCV(cv=None, error_score=nan,
#              estimator=SVC(C=1.0, break_ties=False, cache_size=200,
#                            class_weight=None, coef0=0.0,
#                            decision_function_shape='ovr', degree=3,
#                            gamma='scale', kernel='rbf', max_iter=-1,
#                            probability=False, random_state=None, shrinking=True,
#                            tol=0.001, verbose=False),
#              iid='deprecated', n_jobs=None,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                          'kernel': ['rbf']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=3)

# %%
# print best parameter after tuning
print(grid.best_params_)
# Out:
# {'C': 100, 'gamma': 1, 'kernel': 'rbf'}

# %%
print(grid.best_estimator_)
# Out:
# SVC(C=100, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma=1, kernel='rbf', max_iter=-1,
#     probability=False, random_state=None, shrinking=True, tol=0.001,
#     verbose=False)

# %%
#!pip install catboost
from catboost import CatBoostClassifier
CBC= CatBoostClassifier( )
CBC.fit(xtrain,ytrain )

train_score=score(ytrain,CBC.predict(xtrain))
test_score=score(ytest,CBC.predict(xtest))

print(train_score)
print(test_score)

# %%
preds = svc.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix as cm
cm(ytest,preds)
# Out:
# array([[717, 183],
#        [165, 203]])

# %%
preds = CBC.predict(xtest)
from sklearn.metrics import confusion_matrix as cm
cm(ytest,preds)
# Out:
# array([[786, 114],
#        [146, 222]])

# %%
def calc_score(model,xtrain,ytrain,xtest,ytest):
  model.fit(xtrain,ytrain)
  predict = model.predict(xtrain)
  scr1 = score( ytrain,predict )
  predict1 = model.predict(xtest)
  scr2 = score( ytest,predict1 )
  return scr1,scr2

# %%
def effect(train_score,test_score,x_axis,title):
  plt.style.use("fivethirtyeight")
  plt.style.use("dark_background")
  plt.figure(figsize=(5,5),dpi=129)
  plt.plot(x_axis,train_score,color='orange',label='train_score')
  plt.plot(x_axis,test_score,color='cyan',label='test_score')
  plt.title(title)
  plt.legend()
  plt.xlabel("parameter_value")
  plt.ylabel("roc-auc score")
  plt.show()

# %%
feature_imp = pd.Series(rfc.feature_importances_,index = xtrain.columns)
k = feature_imp.sort_values()

# %%
plt.figure(figsize=(9,5),dpi=120)
plt.barh(k.index,k)
plt.xlabel('Importance')
plt.ylabel('feature_name')
plt.title('feature importance')

# %%
id_col=df_test.ID

# %%
df_test=df_test.drop(labels=['ID'],axis=1)

# %%
df_test['GrandPayment'] = df_test['GrandPayment'].fillna(0)

# %%
df_train['QuarterlyPayment'] = np.round(df_train['QuarterlyPayment'])
df_train['GrandPayment'] = np.round(df_train['GrandPayment'])

# %%
from sklearn.preprocessing import MinMaxScaler
mm_scaler = MinMaxScaler()
col_names_test = list(df_test.columns)
df_mm_test = mm_scaler.fit_transform( df_test )
df_mm_test = pd.DataFrame(df_mm_test, columns=col_names_test)
df_test = df_mm_test
df_test

# %%
def reverse_encoder(x):
    if x==1:
        return 'Yes'
    else:
        return 'No'

# %%
submission=pd.DataFrame({'ID':id_col,'CustomerAttrition':svc.predict( df_test[['GrandPayment','QuarterlyPayment','ServiceSpan','SettlementProcess']]   ) })
submission.CustomerAttrition = submission.CustomerAttrition.apply(reverse_encoder)
act_submission = submission[['ID','CustomerAttrition']]
act_submission.to_csv('/content/drive/MyDrive/Hackathon/IIT KGP/submission.csv',index=False)

# %%
submission

# %%
# Model selection
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import make_scorer
from sklearn.metrics import accuracy_score 
import pprint

# %%
# !pip install scikit-optimize
# Out:
# Collecting scikit-optimize
#   Downloading https://files.pythonhosted.org/packages/8b/03/be33e89f55866065a02e515c5b319304a801a9f1027a9b311a9b1d1f8dc7/scikit_optimize-0.8.1-py2.py3-none-any.whl (101kB)
#      |████████████████████████████████| 102kB 4.1MB/s
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.4.1)
# Collecting pyaml>=16.9
#   Downloading https://files.pythonhosted.org/packages/15/c4/1310a054d33abc318426a956e7d6df0df76a6ddfa9c66f6310274fb75d42/pyaml-20.4.0-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (0.22.2.post1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.19.5)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-optimize) (1.0.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from pyaml>=16.9->scikit-optimize) (3.13)
# Installing collected packages: pyaml, scikit-optimize
# Successfully installed pyaml-20.4.0 scikit-optimize-0.8.1

# %%
# Skopt functions

from skopt import BayesSearchCV
from skopt.callbacks import DeadlineStopper, VerboseCallback, DeltaXStopper
from skopt.space import Real, Categorical, Integer

# %%
def report_perf(optimizer, X, y, title, callbacks=None):
    """
    A wrapper for measuring time and performances of different optmizers
    
    optimizer = a sklearn or a skopt optimizer
    X = the training set 
    y = our target
    title = a string label for the experiment
    """
    start = time()
    if callbacks:
        optimizer.fit(X, y, callback=callbacks)
    else:
        optimizer.fit(X, y)
    d=pd.DataFrame(optimizer.cv_results_)
    best_score = optimizer.best_score_
    best_score_std = d.iloc[optimizer.best_index_].std_test_score
    best_params = optimizer.best_params_
    print((title + " took %.2f seconds,  candidates checked: %d, best CV score: %.3f "
           +u"\u00B1"+" %.3f") % (time() - start, 
                                  len(optimizer.cv_results_['params']),
                                  best_score,
                                  best_score_std))    
    print('Best parameters:')
    pprint.pprint(best_params)
    print()
    return best_params

# %%
acuuracy = make_scorer(accuracy_score, greater_is_better=True, needs_threshold=True)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=0)

# %%
clf = CatBoostClassifier(thread_count=2,
                         loss_function='Logloss',
                         verbose = False)

# %%
# Defining your search space
search_spaces = {'iterations': Integer(10, 300),
                 'depth': Integer(1, 8),
                 'learning_rate': Real(0.01, 1.0, 'log-uniform'),
                 'random_strength': Real(1e-9, 10, 'log-uniform'),
                 'bagging_temperature': Real(0.0, 1.0),
                 'border_count': Integer(1, 255),
                 'l2_leaf_reg': Integer(2, 30),
                 'scale_pos_weight':Real(0.01, 1.0, 'uniform')}

# %%
opt = BayesSearchCV(clf,
                    search_spaces,
                    scoring=accuracy,
                    cv=skf,
                    n_iter=100,
                    n_jobs=1,  # use just 1 job with CatBoost in order to avoid segmentation fault
                    return_train_score=False,
                    refit=True,
                    optimizer_kwargs={'base_estimator': 'GP'},
                    random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-366-b54d05e4f858> in <module>()
#       1 opt = BayesSearchCV(clf,
#       2                     search_spaces,
# ----> 3                     scoring=accuracy,
#       4                     cv=skf,
#       5                     n_iter=100,
#
# NameError: name 'accuracy' is not defined

# %%
best_params = report_perf(opt, X, y,'CatBoost', 
                          callbacks=[VerboseCallback(100), 
                                     DeadlineStopper(60*10)])
